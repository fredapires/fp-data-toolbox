# %% [markdown]
# # **\_scratch**
#
# ---

# %% [markdown]
# <br><br><br>
#
# ## **Objectives**
#
# ---

# %% [markdown]
# Description of dataset and/or problem

# %% [markdown]
# <br><br><br>
#
# ### **Process Diagram**

# %%
import graphviz
graphviz_name  = 'example_pipeline_name' # name the file
graphviz_obj = graphviz.Digraph(graphviz_name) # create Digraph
graphviz_comment = graphviz_name + '\n'+ 'example comment' # displayed at bottom of graph
# graph attributes
graphviz_obj = graphviz.Digraph(
    graphviz_name,
    filename=graphviz_name,
    node_attr={
        'color': 'lightblue', 
        'style': 'filled',
        'shape': 'box',
        },
    )
graphviz_obj.attr(
    size='400,400', 
    rankdir='LR',
    compound='true',
    label=graphviz_comment,
    )
# Definning alias and display name of each node
graphviz_obj.node('1', '1 - Inputs')
graphviz_obj.node('2', '2 - Cleaning + Formatting')
graphviz_obj.node('3', '3 - Feature Creation')
graphviz_obj.node('4', '4 - Processing')
graphviz_obj.node('5', '5 - Predictive Modeling')
graphviz_obj.node('6', '6 - Analysis')
graphviz_obj.node('7', '7 - Visualization')
graphviz_obj.node('8', '8 - Outputs')
# Defining connections between nodes
graphviz_obj.edges(['12', '23', '34', '45', '56', '67', '78', '89'])

#pipeline_graph.render(directory='graphviz-output') # save file to path
graphviz_obj # print of graph

# %% [markdown]
# <br><br><br>
#
# ## **Env Setup**
#
# ---

# %% [markdown]
# <br><br><br>
#
# ### **Imports + Config Setup**

# %%
# imports
import numpy as np
import pandas as pd
import plotly.express as px
# env variables
import dotenv
dotenv.load_dotenv()
df = pd.DataFrame() # creating empty dataframe variable
params = {} # creating empty parameters dictionary
# Magics env settings...
# %matplotlib inline

# %%
def jupyter_notifier_enanble():
    '''
    The setup function sets up notifications for the jupyter_helpers library by defining a WindowsIntegration class 
    that uses the win10toast library to display notifications, and instantiating the Notifications class with the 
    WindowsIntegration class as the integration. The time_threshold parameter is also set to 60 seconds, meaning that 
    notifications will only be shown if the time since the last notification is greater than 60 seconds.
    '''
    from IPython.display import Audio
    from jupyter_helpers.desktop_integration import DesktopIntegration
    class WindowsIntegration(DesktopIntegration):
        def notify(self, title, text, notify_id=None, show_again=True, urgency='normal'):
            from win10toast import ToastNotifier
            toaster = ToastNotifier()
            toaster.show_toast(title, text)
        def notify_close(self, notify_id):
            pass
    from jupyter_helpers.notifications import Notifications
    Notifications(
        time_threshold=60,  # threshold for notification in seconds
        integration=WindowsIntegration
    )

jupyter_notifier_enanble()

# %% [markdown]
# <br><br><br>
#
# ## **Inputs**
#
# ---

# %% [markdown]
# <br><br><br>
#
# ### **Parameter inputs**

# %%
input_file_name = ''

# %% [markdown]
# <br><br><br>
#
# ### **Data ingestion**

# %%
import pandas as pd
# df = pd.read_feather('')

# %% [markdown]
# <br><br><br>
#
# ## **Cleaning + Formatting**
#
# ---

# %%
# convert date fields to datetime dtype (for better pandas based analysis)
# eda.cast_as_datetime(df,'shp_dt');

# %%
# TODO - fill this in later as I work on more projects
# TODO - At some point, transition the data cleaning operations to their own functions

# %% [markdown]
# <br><br><br>
#
# ## **Feature Engineering**
#
# ---

# %%
# TODO - fill this in later as I work on more projects

# %%
# Data processing operations here

# %% [markdown]
# <br><br><br>
#
# ## **Analysis**
#
# ---

# %%
# TODO - fill this in later as I work on more projects

# %%
# Data processing operations here

# %% [markdown]
# <br><br><br>
#
# ## **Predictive Modeling**
#
# ---

# %%
# TODO - fill this in later as I work on more projects

# %%
# Data processing operations here

# %% [markdown]
# <br><br><br>
#
# ## **Visualization**
#
# ---

# %%
# TODO - fill this in later as I work on more projects

# %%
# Data processing operations here

# %% [markdown]
# <br><br><br>
#
# ## **Outputs**
#
# ---

# %%
# Final output operations here

# %%
# stop
